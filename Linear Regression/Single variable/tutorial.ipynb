# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data=pd.read_csv("homeprice.csv")
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
plt.scatter(data.area,data.price)

# %% [markdown]
# **%matplotlib inline** --> it configures matplotlib to generate static images of plots and display them directly in the notebook interface, rather than in separate interactive windows.

# %%
plt.scatter(data.area,data.price,color='red',marker='*')
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
data[['area']]
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(data[['area']],data.price)
# Out:
# LinearRegression()

# %%
#now if we give the area the model will predict the price 
reg.predict([[3300]])
# Out:
# C:\Users\bmvij\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [markdown]
# where linear regression formula is **y=mx+b** where m is coefficient of x and b is the y intercept

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
plt.xlabel('Area',fontsize=20)
plt.ylabel('Price',fontsize=20)
plt.scatter(data.area,data.price,color='red',marker='+')
plt.plot(data.area,reg.predict(data[['area']]),color='green')

# %%
df=pd.read_csv('automating the prediction.csv')
df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df['price']=p

# %%
df
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df.to_csv("prediction.csv",index=False)
